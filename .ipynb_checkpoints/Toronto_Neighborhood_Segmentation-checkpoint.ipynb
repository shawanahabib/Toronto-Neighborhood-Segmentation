# %% [markdown]
# Scrape data from the following wikipedia page: https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M

# %%
import pandas as pd

url =  'https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M'
tables = pd.read_html(url)
headings = ['Postal Code', 'Borough', 'Neighborhood']
tables
# Out:
# [    Postal Code           Borough  \
#  0           M1A      Not assigned
#  1           M2A      Not assigned
#  2           M3A        North York
#  3           M4A        North York
#  4           M5A  Downtown Toronto
#  ..          ...               ...
#  175         M5Z      Not assigned
#  176         M6Z      Not assigned
#  177         M7Z      Not assigned
#  178         M8Z         Etobicoke
#  179         M9Z      Not assigned
#
#                                            Neighborhood
#  0                                         Not assigned
#  1                                         Not assigned
#  2                                            Parkwoods
#  3                                     Victoria Village
#  4                            Regent Park, Harbourfront
#  ..                                                 ...
#  175                                       Not assigned
#  176                                       Not assigned
# ...

# %%
df_nb = tables[0]
df_nb
# Out:
#     Postal Code           Borough  \
# 0           M1A      Not assigned
# 1           M2A      Not assigned
# 2           M3A        North York
# 3           M4A        North York
# 4           M5A  Downtown Toronto
# ..          ...               ...
# 175         M5Z      Not assigned
# 176         M6Z      Not assigned
# 177         M7Z      Not assigned
# 178         M8Z         Etobicoke
# 179         M9Z      Not assigned
#
#                                           Neighborhood
# 0                                         Not assigned
# 1                                         Not assigned
# 2                                            Parkwoods
# 3                                     Victoria Village
# 4                            Regent Park, Harbourfront
# ..                                                 ...
# 175                                       Not assigned
# 176                                       Not assigned
# ...

# %% [markdown]
# Clean data frame

# %%
# remove cells with a borough that is "Not assigned"
df_nb.drop(df_nb[df_nb.Borough =='Not assigned'].index, inplace = True)
df_nb.reset_index(drop=True, inplace = True)
df_nb
# Out:
#     Postal Code           Borough  \
# 0           M3A        North York
# 1           M4A        North York
# 2           M5A  Downtown Toronto
# 3           M6A        North York
# 4           M7A  Downtown Toronto
# ..          ...               ...
# 98          M8X         Etobicoke
# 99          M4Y  Downtown Toronto
# 100         M7Y      East Toronto
# 101         M8Y         Etobicoke
# 102         M8Z         Etobicoke
#
#                                           Neighborhood
# 0                                            Parkwoods
# 1                                     Victoria Village
# 2                            Regent Park, Harbourfront
# 3                     Lawrence Manor, Lawrence Heights
# 4          Queen's Park, Ontario Provincial Government
# ..                                                 ...
# 98       The Kingsway, Montgomery Road, Old Mill North
# 99                                Church and Wellesley
# ...

# %%
# check if there are any rows with Neighborhood value 'Not assigned'
df_nb['Neighborhood'].str.contains('Not Assigned').value_counts()
# Out:
# False    103
# Name: Neighborhood, dtype: int64

# %% [markdown]
# Obtain the latitude and longitude for each location

# %%
import numpy
#! pip install pgeocode -- uncomment this line if pgeocode not already installed
import pgeocode

nomi = pgeocode.Nominatim('ca')
latitude = []
longitude = []
for i in range(0,len(df_nb)):
    loc = nomi.query_postal_code(df_nb['Postal Code'][i])
    latitude.append(loc.latitude)
    longitude.append(loc.longitude)
print(latitude,longitude)
# Out:
# [43.7545, 43.7276, 43.6555, 43.7223, 43.6641, 43.6662, 43.8113, 43.745, 43.7063, 43.6572, 43.7081, 43.6505, 43.7878, 43.7334, 43.6913, 43.6513, 43.6915, 43.6437, 43.7678, 43.6784, 43.6456, 43.6889, 43.7712, 43.7124, 43.6564, 43.6683, 43.7686, 43.8015, 43.7535, 43.7059, 43.6496, 43.6655, 43.7464, 43.7801, 43.7694, 43.6872, 43.62300000000001, 43.648, 43.7298, 43.7797, 43.739, 43.6803, 43.6469, 43.6383, 43.7122, 43.7547, 43.7334, 43.6693, 43.6492, 43.7137, 43.7598, 43.7247, 43.7915, 43.7319, 43.6561, 43.7335, 43.6934, 43.7366, 43.6952, 43.7673, 43.7568, 43.7301, 43.7113, 43.6748, 43.7068, 43.7612, 43.75, 43.7135, 43.6966, 43.6605, 43.6949, 43.7507, 43.7786, 43.7143, 43.6736, 43.6469, nan, 43.6898, 43.7946, 43.702, 43.6629, 43.6512, 43.7812, 43.6899, 43.6541, 43.8177, 43.6861, 43.6404, 43.6075, 43.7432, 43.8016, 43.6827, 43.6437, 43.6021, 43.7144, 43.834, 43.6684, 43.6492, 43.6518, 43.6656, 43.7804, 43.6325, 43.6256] [-79.33, -79.3148, -79.3626, -79.4504, -79.3889, -79.5282, -79.193, -79
# ...

# %%
# add lat, long to dataframe
df_nb['latitude'] = latitude
df_nb['longitude'] = longitude
df_nb
# Out:
#     Postal Code           Borough  \
# 0           M3A        North York
# 1           M4A        North York
# 2           M5A  Downtown Toronto
# 3           M6A        North York
# 4           M7A  Downtown Toronto
# ..          ...               ...
# 98          M8X         Etobicoke
# 99          M4Y  Downtown Toronto
# 100         M7Y      East Toronto
# 101         M8Y         Etobicoke
# 102         M8Z         Etobicoke
#
#                                           Neighborhood  latitude  longitude
# 0                                            Parkwoods   43.7545   -79.3300
# 1                                     Victoria Village   43.7276   -79.3148
# 2                            Regent Park, Harbourfront   43.6555   -79.3626
# 3                     Lawrence Manor, Lawrence Heights   43.7223   -79.4504
# 4          Queen's Park, Ontario Provincial Government   43.6641   -79.3889
# ..                                                 ...       ...        ...
# ...
